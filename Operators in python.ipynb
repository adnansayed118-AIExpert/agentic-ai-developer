# %% [markdown]
# # Operators in Python
#
# An operator in Python is a symbol or keyword used to perform operations on variables and values (operands).
#
# Although the + operator is often used to add together two values, like in the example above, it can also be used to add together a variable and a value, or two variables:
#
# Arithmetic Operators   + - * / // % **
# Assignement operators  = +=,-=,*=,/=,//=,%=
# Relational operators  >,<,<=,>=,!=,==\
# urinary              minus -
# logical operator    AND, OR, NOT

# %% [markdown]
# # Arithmetic operators

# %%
x1,y1=10,5
x1+y1
# Out:
# 15

# %%
x1-y1
# Out:
# 5

# %%
x1*y1
# Out:
# 50

# %%
x1/y1
# Out:
# 2.0

# %%
x1//y1
# Out:
# 2

# %%
x1%y1
# Out:
# 0

# %%
x1%%y1
# Out:
#   File "C:\Users\ADNANP~2\AppData\Local\Temp/ipykernel_12292/728572700.py", line 1
#     x1%%y1
#        ^
# SyntaxError: invalid syntax

# %%
x2=2
y2=4
x2**y2
# Out:
# 16

# %%
sum1 = 100 + 50      # 150 (100 + 50)
sum2 = sum1 + 250    # 400 (150 + 250)
sum3 = sum2 + sum2   # 800 (400 + 400)

print (sum1)
print (sum2)
print (sum3)
# Out:
# 150
# 400
# 800

# %% [markdown]
# # Assignment operators
#
# Assignment operators are used to assign values to variables:

# %%
x=5
x
# Out:
# 5

# %%
x=5
x += 3
print(x)
# Out:
# 8

# %%
x=5
x -= 3
print(x)
# Out:
# 2

# %%
x=5
x *= 3
print(x)
# Out:
# 15

# %%
x=5
x /= 3
print(x)
# Out:
# 1.6666666666666667

# %%
x=5
x //= 3
print(x)
# Out:
# 1

# %%
x=5
x %= 3
print(x)
# Out:
# 2

# %%
x=5
x &= 3
print(x)
# Out:
# 1

# %%
x=5
x |= 3
print(x)
# Out:
# 7

# %%
x=5
x >>= 3
print(x)
# Out:
# 0

# %%
x=5
x := 3
print(x)
# Out:
#   File "C:\Users\ADNANP~2\AppData\Local\Temp/ipykernel_12292/4192862629.py", line 2
#     x := 3
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Relational operators
#
# Comparison operators are used to compare two values:

# %%
a=5
b=10
a<b
# Out:
# True

# %%
a=5
b=10
a>b
# Out:
# False

# %%
a=5
b=10
a>>b
# Out:
# 0

# %%
a=5
b=10
a!=b
# Out:
# True

# %%
a=5
b=10
a==b
# Out:
# False

# %%
a=5
b=10
a>=b
# Out:
# False

# %%
a=5
b=10
a<=b
# Out:
# True

# %%
a=5
b=10
a!=b
# Out:
# True

# %%
a=5
b=10
a==b
# Out:
# False

# %% [markdown]
# # Urinary operators
#
# Uni means 1|| binary means 2
#
# Here we are adding unary minus operator (-) on the operand value of m becomes -7, which indicate it has negative values

# %%
m=7
m
# Out:
# 7

# %%
n= - (m)
n
# Out:
# -7

# %% [markdown]
# # logical operator
#
# In logical oprator 1 AND 1 is 1 rest of all is zero whereas 0 OR 0 is - rest of all are 1

# %%
a=5
b=4

a<8 and b<8
# Out:
# True

# %%
a<8 and b>8
# Out:
# False

# %%
a<8 or b<8
# Out:
# True

# %%
a<8 or b>8
# Out:
# True

# %%
a>8 or b>8
# Out:
# False
