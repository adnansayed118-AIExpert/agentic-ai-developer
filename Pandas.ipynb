# %% [markdown]
# # Pandas
#
# Pandas is a library that handled dataframe and DataFrame is a table consisting of rows and columns
# It is a powerful python data analysis toolkit
#
#
# # Main features of Pandas
#
# --> It handled missing data
#
# --> Using Pandas you can perform insertion and deletion (It is a mutable)
#
# --> Data alignment
#
# --> using Pandas we can perform groupby()
#
# --> dataframe indexing and Slicing
#
# --> merging dataset
#
# --> Reshaping and pivot (to check rows and columns)
#
# --> using Pandas you can read excel,hdfs,PDF,html,
#
# --> Time series model
#
#
# # what is raw data?
#
# The data set which has  missing value is called  raw dataset.
#
#
# # What is clean data?
#
#
# The data set which has cleaned data or not having msssing value is called  clean dataset.
#
#
# # what is data cleaning or Data cleansing ?
#
# Someone who clean raw data  to clean data is called data cleaning or Data cleansing and this is the task of Data Analysit
#
# #  Work flows of data analyst
#
# --> Data Analyst are one who clean Raw data to clean  dataset and build ML predictive model  then  ML OPs and then CICD PIlpe line
#
# Raw dataset--> clean data --> clean dataset  created --> ML model -->model testing -->Model predictive with live data--> front end creation-->deployment --> ML Ops --> CI/CD pipeline
#
#
# # In data Science , excel files term as Data Set
#
# # in excel sheets we have rows and colums but in Data Science these colums called as attributes|features| variable.
#
# Excel sheet --> Rows and colums (Non technical terms)
# Data Set    --> Records and Attributes(technical terms)
# arguments == Parameter
# Package == Library
# Function with arguments
# Function without arguments

# %%
Project Country GDP analsysi || country economy analysis

Dataset contains 195 records and 5 attributes
2 numerical attriutes == number
3 text attributes == text
