# %% [markdown]
# # Data Structure
#
# What is the difference between data type and Data Structures?
#
# In Data type , user defined only one value
# In Data Structure, user can defined more than one value , There are five different type of DS  as mentioned below:-
#
# list  []
# tuple ()
# set   {}
# dic
# range

# %% [markdown]
# # List:- always defined with square bracket []
#
# 1) List is an ordered sequence of items and a mutable collection that allows duplicate values.
#
# 2) We can have different data types under a list. E.g we can have integer, float and string items in a same list.
#
#
# 🔹 Features:
#
# Ordered ✅
#
# Mutable (can change values) ✅
#
# Allows duplicates ✅
#
# Indexed ✅
#
# --> Append function is allowed , which add the number at last
# --> duplication is allowed
# --> copy() is allowed, copy will be allowed from one list to another list
# --> Multiple data type is allowed in a llist
# --> List is growable
# --> clear() it will clear the element from list
# --> del l it will delete the list variable
# --> count() function, it will count the numbers to oocurances/elements available in a list
#
#
# # ** How many times a word repeate in a string?
#
# Ans:- using count () we can find out the number of times word repeate
#
# --> extend() function extend one list to another list which is concatenation
#
# --> index() function will return the number of position of an element in a list
#
# --> insert(index,object) function it will insert an object before an index value mention
#
# --> pop() if you dont pass any argument then only it will remove the last value , delete and display the last value
#
#     |--> #pop(index=-1,/) remove and return item at index (default last)
#     --> pop(3) pop function with argument will remove the specific index from list.
#
#
# # ***difference between pop() without argument VS pop (3) with argument
#
#
# pop() without argument              ||                 #pop (3) with argument
#
# =========================                          ============================
#
#
# be default it will remove the       ||              it will remove only specific index from list
#
# last element from the list
#
# --> remove() function remove based on value/element
#
#
# # ***difference between pop() function VS remove()
#
# pop() with or without arugument                      ||            remove function()
#
# =========================                            ||            =========================
#
#
# pop() will remove based on index                     ||            remove() function remove based on value/element
#
#
#
# # Type of python errors:-
#
# syntax error
# Name error
# Zero division error
# indexing error
# value error for eg. list 50th index is not in a list

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# creating an empty list, will print empty 

l=[]
l
# Out:
# []

# %%
type(l)
# Out:
# list

# %%
len(l)
# Out:
# 0

# %%
l.append(10)
l
# Out:
# [10]

# %%
l.append(20,30) #list.append() takes exactly one argument (2 given)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\ADNANP~2\AppData\Local\Temp/ipykernel_10332/3652299888.py in <module>
# ----> 1 l.append(20,30) #list.append() takes exactly one argument (2 given)
#
# TypeError: list.append() takes exactly one argument (2 given)

# %%
l.append(20)
l.append(30)
l.append(40)
l.append(50)
l.append(60)
l.append(70)
l
# Out:
# [10, 20, 30, 40, 50, 60, 70]

# %%
len(l)
# Out:
# 7

# %%
l.append(10) # if you want to add 10 one more time then you can apend it but it will reflect in the end

# %%
l
# Out:
# [10, 20, 30, 40, 50, 60, 70, 20, 30, 40, 50, 60, 70, 10]

# %%
l1=[]
l1
# Out:
# []

# %%
l1= l.copy()
l1
# Out:
# [10, 20, 30, 40, 50, 60, 70, 10]

# %%
l ==l1
# Out:
# True

# %%
print(id(l))
print(id(l1)) # values stores in both variable will be same but addresss will be different as in data type address will be same
               but in Data structure will be different
# Out:
#   File "C:\Users\ADNANP~2\AppData\Local\Temp/ipykernel_10332/2652488995.py", line 3
#     but in Data structure will be different
#     ^
# IndentationError: unexpected indent

# %%
print(l)
print(l1)
# Out:
# [10, 20, 30, 40, 50, 60, 70, 10]
# [10, 20, 30, 40, 50, 60, 70, 10]

# %%
l2=[]
l2
# Out:
# []

# %%
l2.append(2)
l2.append(2.3)
l2.append(True)
l2.append(1+2j)
l2.append('nit')
l2.append([1,2,3])

# %%
l2 # nested list = list in a list is called as Nested list
   # we can apply multiple data type in a nested list
# Out:
# [2, 2.3, True, (1+2j), 'nit', [1, 2, 3]]

# %%
print(l)
print(l1)
print(l2)
# Out:
# [10, 20, 30, 40, 50, 60, 70, 10]
# [10, 20, 30, 40, 50, 60, 70, 10]
# [2, 2.3, True, (1+2j), 'nit', [1, 2, 3]]

# %%
l
# Out:
# [10, 20, 30, 40, 50, 60, 70, 20, 30, 40, 50, 60, 70, 10]

# %%
l.clear()  # it will clear the element from list

# %%
l
# Out:
# []

# %%
del l        #del l   it will delete the list variable

# %%
l
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\ADNANP~2\AppData\Local\Temp/ipykernel_10332/3723490112.py in <module>
# ----> 1 l
#
# NameError: name 'l' is not defined

# %%
print(l1)
print(l2)
# Out:
# [10, 20, 30, 40, 50, 60, 70, 20, 30, 40, 50, 60, 70, 10]
# [2, 2.3, True, (1+2j), 'nit', [1, 2, 3]]

# %%
l1.count(20)
# Out:
# 2

# %%
l1.count(10) #count() function, it will count the numbers to oocurances/elements available in a list
# Out:
# 2

# %%
l1
l2
# Out:
# [2, 2.3, True, (1+2j), 'nit', [1, 2, 3]]

# %%
l1.extend(l2)
l1            #  extend() function extend one list to another list which is concatenation
# Out:
# [10, 20, 30, 40, 50, 60, 70, 10, 2, 2.3, True, (1+2j), 'nit', [1, 2, 3]]

# %%
print(l1)
print(l2)
# Out:
# [10, 20, 30, 40, 50, 60, 70, 20, 30, 40, 50, 60, 70, 10, 2, 2.3, True, (1+2j), 'nit', [1, 2, 3]]
# [2, 2.3, True, (1+2j), 'nit', [1, 2, 3]]

# %%
l1.index(10)   #index()  function  will return the number of position of an element in a list
# Out:
# 0

# %%
l1.index(True)
# Out:
# 10

# %%
l1.index('nit')
# Out:
# 12

# %%
l1.index(2.3)
# Out:
# 9

# %%
l1.index(200)  # it will return a value error as 200 is not in list
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\ADNANP~2\AppData\Local\Temp/ipykernel_10332/1103392025.py in <module>
# ----> 1 l1.index(200)  # it will return a value error as 200 is not in list
#
# ValueError: 200 is not in list

# %%
l2.index([1,2,3])
# Out:
# 5

# %%
l2
# Out:
# [2, 2.3, True, (1+2j), 'nit', [1, 2, 3]]

# %%
for i in l2:
    print(i)
# Out:
# 2
# 2.3
# True
# (1+2j)
# nit
# [1, 2, 3]

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 60, 70, 10, 2, 2.3, True, (1+2j), 'nit', [1, 2, 3]]

# %%
l1.insert(1,15) #insert(index,object) function  it will insert an object before an index value mention
l1
# Out:
# [10,
#  15,
#  20,
#  30,
#  40,
#  50,
#  60,
#  70,
#  20,
#  30,
#  40,
#  50,
#  60,
#  70,
#  10,
#  2,
#  2.3,
#  True,
#  (1+2j),
#  'nit',
#  [1, 2, 3]]

# %%
l1.insert(5,25)

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 25, 60, 10, 2, 2.3, True, (1+2j), 'nit', [1, 2, 3]]

# %%
salary=[2000,5000,8000,1000]
salary
# Out:
# [2000, 5000, 8000, 1000]

# %%
salary=[2000,5000,8000,1000]
salary[0]
# Out:
# 2000

# %%
salary=[2000,5000,8000,1000]
salary[1]
# Out:
# 5000

# %%
salary[3]
# Out:
# 1000

# %%
l2
# Out:
# [2, 2.3, True]

# %%
l2.append((1+2j))
l2.append('nit')
l2.append([1, 2, 3])
l2.append([4,5,6])
l2
# Out:
# [2, 2.3, True, (1+2j), 'nit', [1, 2, 3], [4, 5, 6]]

# %%
l2.pop()                #pop(index=-1,/) remove and return  item at index (default last)
# Out:
# [4, 5, 6]

# %%
l2
# Out:
# [2, 2.3, True, (1+2j), 'nit', [1, 2, 3], (1+2j), (1+2j)]

# %%
l2.append((1+2j))
l2
# Out:
# [2, 2.3, True, (1+2j), 'nit', [1, 2, 3], (1+2j), (1+2j)]

# %%
l2
# Out:
# [2, 2.3, True, (1+2j), 'nit', [1, 2, 3], (1+2j), (1+2j)]

# %%
l2.pop(4)  # it will remove 3rd index of the list
l2
# Out:
# [2, 2.3, True, (1+2j), [1, 2, 3], (1+2j), (1+2j)]

# %%
l1.pop(50)  # since there is no 50th index in our list so it will return IndexError: pop index out of range
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# C:\Users\ADNANP~2\AppData\Local\Temp/ipykernel_10332/3582048623.py in <module>
# ----> 1 l1.pop(50)  # since there is no 50th index in our list so it will return IndexError: pop index out of range
#
# IndexError: pop index out of range

# %%
l2.remove((1+2j)) # remove function remove based on value/element

# %%
l2
# Out:
# [2, 2.3, True, [1, 2, 3], (1+2j), (1+2j)]

# %%
l2.remove((1+2j))

# %%
l2
# Out:
# [2, 2.3, True, [1, 2, 3], (1+2j)]

# %%
l2
# Out:
# [2, 2.3, True, [1, 2, 3]]

# %%
l2.remove(True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\ADNANP~2\AppData\Local\Temp/ipykernel_10332/3659915606.py in <module>
# ----> 1 l2.remove(True)
#       2 l2
#
# ValueError: list.remove(x): x not in list

# %%
l2
# Out:
# [2, 2.3, [1, 2, 3]]

# %%
l1
# Out:
# [2, 2.3, True]

# %%
l1.remove(2.3)
l1
# Out:
# [2, True]

# %%
txt = " abc def ghi "    # Left Strip it removes spaces or specified characters from the LEFT side (beginning) of a string.
 
txt.lstrip()
# Out:
# 'abc def ghi '

# %%
txt = " abc def ghi "  # Strip removes spaces or specified characters from BOTH sides (left and right) of a string.
                        #it does not remove characters from the middle (Middle spaces remain)
 
txt.strip()
# Out:
# 'abc def ghi'

# %%
txt = " abc def ghi   " # Right Strip It removes spaces or specified characters from the RIGHT side (end) of a string
                        #It does not affect the left side or middle.
txt.rstrip()
# Out:
# ' abc def ghi'

# %% [markdown]
# # Using Escape Character

# %%
#Using double quotes in the string is not allowed. 
mystr = "My favourite TV Series is "Game of Thrones""
# Out:
#   File "C:\Users\ADNANP~2\AppData\Local\Temp/ipykernel_10332/942512744.py", line 2
#     mystr = "My favourite TV Series is "Game of Thrones""
#                                         ^
# SyntaxError: invalid syntax

# %%
#Using escape character to allow illegal characters 
mystr = "My favourite series is \"Game of Thrones\"" 
print(mystr)
# Out:
# My favourite series is "Game of Thrones"

# %%
list1 = [] # Empty List

# %%
print(type(list1))
# Out:
# <class 'list'>

# %%
list2 = [10,30,60] # List of integers numbers

# %%
list3 = [10.77,30.66,60.89] # List of float numbers

# %%
list4 = ['one','two' , "three"] # List of strings

# %%
list5 = ['Asif', 25 ,[50, 100],[150, 90]] # Nested Lists

# %%
list6 = [100, 'Asif', 17.765] # List of mixed data types

# %%
list7 = ['Asif', 25 ,[50, 100],[150, 90] , {'John' , 'David'}]

# %%
len(list6) #Length of list
# Out:
# 3

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
list2[0] # Retreive first element of the list
# Out:
# 10

# %%
list4[0] # Retreive first element of the list
# Out:
# 'one'

# %%
list4[0][0] # Nested indexing - Access the first character of the first list element
# Out:
# 'o'

# %%
list4[0][2]
# Out:
# 'e'

# %%
list4[-1] # Last item of the list
# Out:
# 'three'

# %%
list5[-1] # Last item of the list
# Out:
# [150, 90]

# %% [markdown]
# #  List Slicing

# %%
mylist = ['one' , 'two' , 'three' , 'four' , 'five' , 'six' , 'seven' , 'eight']

# %%
mylist[0:3] # Return all items from 0th to 3rd index location excluding the item
# Out:
# ['one', 'two', 'three']

# %%
mylist[2:5] # List all items from 2nd to 5th index location excluding the item a
# Out:
# ['three', 'four', 'five']

# %%
mylist[:3] # Return first three items
# Out:
# ['one', 'two', 'three']

# %%
mylist[:2] # Return first two items
# Out:
# ['one', 'two']

# %%
mylist[-3:] # Return last three items
# Out:
# ['six', 'seven', 'eight']

# %%
mylist[-2:] # Return last two items
# Out:
# ['seven', 'eight']

# %%
mylist[-1] # Return last item of the list
# Out:
# 'eight'

# %%
mylist[:] # Return whole list
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
mylist[:-4]
# Out:
# ['one', 'two', 'three', 'four']

# %% [markdown]
# # Add , Remove & Change Items

# %%
mylist

# %%
mylist.append('nine') # Add an item to the end of the list 
mylist
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']

# %% [markdown]
# #  All / Any
#
# The all() method returns:
#
# True - If all elements in a list are true
# False - If any element in a list is false
#
# The any() function returns True if any element in the list is True. If not, any() returns False.

# %%
L1 = [1,2,3,4,0]

# %%
all(L1) # Will Return false as one value is false (Value 0)
# Out:
# False

# %%
any(L1) # Will Return True as we have items in the list with True value
# Out:
# True

# %%
L2 = [1,2,3,4,True,False] 
L2
# Out:
# [1, 2, 3, 4, True, False]

# %%
any(L2) # Will Return True as we have items in the list with True value
# Out:
# True

# %%
L3 = [1,2,3,True] 
L3
# Out:
# [1, 2, 3, True]

# %%
all(L3)
# Out:
# True

# %%
any(L3)
# Out:
# True

# %% [markdown]
# # all(L3) # Will return True as all items in the list are True

# %%
l1[:]
# Out:
# [10, 20, 30, 40, 25, 60, 10, 2, 2.3, True, (1+2j), 'nit', [1, 2, 3]]

# %%
l1[::2]
# Out:
# [10, 30, 25, 10, 2.3, (1+2j), [1, 2, 3]]

# %%
l1[::3]
# Out:
# [10, 40, 10, True, [1, 2, 3]]

# %%
l1[2:10:4]
# Out:
# [30, 10]

# %%
l1=l2.copy()

# %%
l1
# Out:
# [2, 2.3, True]

# %%
l2
# Out:
# [2, 2.3, True]

# %%
l1
# Out:
# [2, 2.3, True]

# %%
l3=['a','b','c']
l3
# Out:
# ['a', 'b', 'c']

# %%
l3[-4:]
# Out:
# ['a', 'b', 'c']

# %%
l3[2]=400

# %%
l3
# Out:
# ['a', 'b', 400]

# %%
l1
# Out:
# [2, 2.3, True]

# %%
l1[10]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# C:\Users\ADNANP~2\AppData\Local\Temp/ipykernel_10332/901076641.py in <module>
# ----> 1 l1[10]
#
# IndexError: list index out of range

# %%
#nested indexing (index inside index)

print(l1[2][0])
print(l1[1][1])
print(l1[0][2])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\ADNANP~2\AppData\Local\Temp/ipykernel_10332/3120302045.py in <module>
#       1 #nested indexing (index inside index)
#       2
# ----> 3 print(l1[2][0])
#       4 print(l1[1][1])
#       5 print(l1[0][2])
#
# TypeError: 'bool' object is not subscriptable

# %%
l1
# Out:
# [2, 2.3, True]

# %%
l3=[1,2,3]

# %%
l3[::-1]==3,2,1
# Out:
# (False, 2, 1)

# %%
l3.reverse()

# %%
l3
# Out:
# [3, 2, 1]

# %%
l3.sort()

# %%
l3
# Out:
# [1, 2, 3]

# %%
l3.sort(reverse=True)

# %%
l3
# Out:
# [3, 2, 1]

# %%
l1
# Out:
# [2,
#  2.3,
#  True,
#  (1+2j),
#  'nit',
#  [1, 2, 3],
#  2,
#  2.3,
#  True,
#  (1+2j),
#  'nit',
#  [1, 2, 3]]

# %%
l1.sort()  # sort function always works with similar data types if you pased different data types then it will through an error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\ADNANP~2\AppData\Local\Temp/ipykernel_10332/2406146923.py in <module>
# ----> 1 l1.sort()
#
# TypeError: '<' not supported between instances of 'complex' and 'int'

# %% [markdown]
# # Joining a list using a '+'operator

# %%
list1 = ['one', 'two', 'three', 'four'] 
list2 = ['five', 'six', 'seven', 'eight']
print(list1)
print(list2)
# Out:
# ['one', 'two', 'three', 'four']
# ['five', 'six', 'seven', 'eight']

# %%
list3=list1+list2
print(list3)
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
list1.extend(list2)
list1
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
list1
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %% [markdown]
# # List Membership

# %%
list1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\ADNANP~2\AppData\Local\Temp/ipykernel_10332/40393744.py in <module>
# ----> 1 list1
#
# NameError: name 'list1' is not defined

# %%
'one' in list1 # Check if 'one' exist in the list
# Out:
# True

# %%
'ten' in list1
# Out:
# False

# %%
if 'three' in list1:
    print('Three is present in the list1')
else: 
    print('Three is not present in the list')
# Out:
# Three is present in the list1

# %%
if 'eleven' in list1: # Check if 'eleven' exist in the list 
    print('eleven is present in the list') 
else: 
    print('eleven is not present in the list')
# Out:
# eleven is not present in the list

# %% [markdown]
# # Reverse & Sort List

# %%
list1
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
list1.reverse()

# %%
list1
# Out:
# ['eight', 'seven', 'six', 'five', 'four', 'three', 'two', 'one']

# %%
list1.sort()

# %%
list1
# Out:
# ['eight', 'five', 'four', 'one', 'seven', 'six', 'three', 'two']

# %%
list1=list1[::-1]
list1
# Out:
# ['two', 'three', 'six', 'seven', 'one', 'four', 'five', 'eight']

# %%
del list1

# %%
list1 = ['one', 'two', 'three', 'four']

# %%
list2 = ['five', 'six', 'seven', 'eight']

# %%
list1.extend(list2)

# %%
list1
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
list1.reverse()
list1
# Out:
# ['eight', 'seven', 'six', 'five', 'four', 'three', 'two', 'one']

# %%
list1=list1[::-1]

# %%
list1
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %% [markdown]
# # Sort () function
# # Sort list in ascending order

# %%
my_list=[9,12,8,4,17,20]
my_list
# Out:
# [9, 12, 8, 4, 17, 20]

# %%
my_list.sort()
my_list
# Out:
# [4, 8, 9, 12, 17, 20]

# %% [markdown]
#  # Sort list in descending order

# %%
my_list
# Out:
# [4, 8, 9, 12, 17, 20]

# %%
my_list.sort(reverse=True)
my_list
# Out:
# [20, 17, 12, 9, 8, 4]

# %%
my_list1=[25,14,32,40,47,62,80]
my_list1
# Out:
# [25, 14, 32, 40, 47, 62, 80]

# %%
sorted(my_list1) # Returns a new sorted list and doesn't change original list
# Out:
# [14, 25, 32, 40, 47, 62, 80]

# %%
my_list1
# Out:
# [25, 14, 32, 40, 47, 62, 80]

# %% [markdown]
# # Loop through a list

# %%
list1
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
for i in list1:
    print (i)
# Out:
# one
# two
# three
# four
# five
# six
# seven
# eight

# %% [markdown]
# # enumerate()
#
# enumerate() is a built-in Python function that adds a counter (index) to an iterable (like list, tuple, string, etc.) and returns it as an enumerate object.
#
# 👉 It is mainly used in loops when you need both index and value.
#
# --> Syntax
# enumerate(iterable, start=0)
#
# iterable → list, tuple, string, etc.
#
# start → optional starting index (default = 0)

# %%
for i in enumerate(list1):
    print(i)
# Out:
# (0, 'one')
# (1, 'two')
# (2, 'three')
# (3, 'four')
# (4, 'five')
# (5, 'six')
# (6, 'seven')
# (7, 'eight')
