# %% [markdown]
# <a href="https://colab.research.google.com/github/adnansayed118-AIExpert/agentic-ai-developer/blob/main/Datatypes_in_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Pyhton Datatypes
int     is value without decimal
float   is a value with decimal, only e letter is allowed (letter is a syntax) ** 'e' for exponential
bool
complex
string

# %%
4 # int with variable
# Out:
# 4

# %%
10 # int with variable
# Out:
# 10

# %%
_ + 10 # '_' in pyhton will store the last value, +10 will add value to it
# Out:
# 20

# %%
_ - 5 # '_' in pyhton will store the last value, -5 will substract value from it
# Out:
# 15

# %%
_ * 3 # in pyhton _ will store the last value,* 3 will multiply value to it
# Out:
# 45

# %%
_ / 3  # in python _ will store last value, _ / 3 will divide from last value and result will show you in float type
# Out:
# 15.0

# %%
i = 10
i
# Out:
# 10

# %%
_ + 20
# Out:
# 30

# %%
int (i)
# Out:
# 10

# %%
id (i)
# Out:
# 11654664

# %%
type (i)
# Out:
# int

# %% [markdown]
# # float   value with decimal only e letter is allow , a letter 'e' is a syntax which is called as exponential value.
# e0=1.0
# e1=10.0
# e2=100.0
# e3=1000.0
# e4=10000.0
# e5=100000.0 and so on

# %%
petrol_price = 20.50
petrol_price
# Out:
# 20.5

# %%
gold_price = 1100000.00
gold_price
# Out:
# 1100000.0

# %%
f2 = 2e0
f2
# Out:
# 2.0

# %%
type (f2)
# Out:
# float

# %%
f3=2.5e2
f3
# Out:
# 250.0

# %%
f4=3.4e3
f4
# Out:
# 3400.0

# %%
id (f4)
# Out:
# 139601967894768

# %%
type (f4)
# Out:
# float

# %% [markdown]
# # bool (Boolean) is a data type having True or False.
#
# It cannot be written as captial or small letter, will thrown an error.
# Always first letter will be captial and remaing small.
#
# In backend True value has 1
#             False value has 0

# %%
TRUE
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3320712247.py in <cell line: 0>()
# ----> 1 TRUE
#
# NameError: name 'TRUE' is not defined

# %%
true
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-592217714.py in <cell line: 0>()
# ----> 1 true
#
# NameError: name 'true' is not defined

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
None

# %%
True + True
# Out:
# 2

# %%
True + False
# Out:
# 1

# %%
False + True
# Out:
# 1

# %%
False + False
# Out:
# 0

# %%
print (True + True)
print (False + True)
print (False + False)
print (False - False)
print (False + False)
# Out:
# 2
# 1
# 0
# 0
# 0

# %%
10/2 # float divison
# Out:
# 5.0

# %%
False / True
# Out:
# 0.0

# %%
f5 = False // True
f5
type (f5)
# Out:
# int

# %%
True / False # will get here 'ZeroDivisionError' because of division by zero
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipython-input-2917913318.py in <cell line: 0>()
# ----> 1 True / False
#
# ZeroDivisionError: division by zero

# %% [markdown]
# # Complex Datatype
#  -- This datatype not available in java but only available in python for handling high end math project.
#
# format of complex datatype is written as **a + bj**
# where as is a real part, b is an imaginary part with j is square root of -1
#
# note:- **a + bj** , here only letter j or J is allowed no other letter is allowed

# %%
c = 10 + 20j
c
# Out:
# (10+20j)

# %%
id (c)
# Out:
# 139601967896016

# %%
type (c)
# Out:
# complex

# %%
d = 20 +30j
d
# Out:
# (20+30j)

# %%
print (10 + 20j)
print (20 + 30j)
# Out:
# (10+20j)
# (20+30j)

# %%
print (c)
print (d)
# Out:
# (10+20j)
# (20+30j)

# %%
print (c+d)
# Out:
# (30+50j)

# %% [markdown]
# #example for complex
#
# addition of 2 complex datasets , system will understand real value to be added with real and imaginary value to be added with imaginary party. That's why python is called as dynamix programming language.
#
# c = (10 + 20j)
# d = (20 + 30j)
# =================
#      (30 + 50j)
# ================

# %%
c.imag
# Out:
# 20.0

# %%
c.real
# Out:
# 10.0

# %%
c.conjugate
# Out:
# <function complex.conjugate()>

# %% [markdown]
# # String Datatype
#
# In python, string type can  be written as ' ' , " ",''' ''' or as " "
# signle /double/triple quotes
#
# conditon:- If user has single lines of code then use '' and ""
#           if user has multiple lines of code then use ''' '''
#
#
#
# Day by day text are increasing , to handle this we need LLM model (Large Language Model) born.
# Some of the example of LL moel are as  below:-
#
# *Claude (Antropic) -- MCP Model Context Protocol
# ChatGpt (OpenAI)
# Gemini (Google deepmind resarch company for google)
# Llama (Facebook or meta)
# deepseek (Deepseek)
# grok (xai)
# kimi (moonshot ai)
# qwen (Alibaba)

# %%
'welcome to Naresh IT'
# Out:
# 'welcome to Naresh IT'

# %%
"welcome to Naresh IT"
# Out:
# 'welcome to Naresh IT'

# %%
''' welcome to Naresh IT  '''
# Out:
# ' welcome to Naresh IT  '

# %%
welcome to Naresh IT
ameerpet
hydrabad
telangana
# Out:
#   File "/tmp/ipython-input-1748973132.py", line 1
#     welcome to Naresh IT
#             ^
# SyntaxError: invalid syntax

# %%
'welcome to Naresh IT
ameerpet
hydrabad
telangana'
# Out:
#   File "/tmp/ipython-input-844033924.py", line 1
#     'welcome to Naresh IT
#     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
"welcome to Naresh IT
ameerpet
hydrabad
telangana"
# Out:
#   File "/tmp/ipython-input-3656567899.py", line 1
#     "welcome to Naresh IT
#     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
''' welcome to Naresh IT
ameerpet
hydrabad
telangana '''
# Out:
# ' welcome to Naresh IT\nameerpet\nhydrabad\ntelangana '
