# %% [markdown]
# # Matplotlib is a low level graph plotting library in python that serves as a visualization utility.
#
# Matplotlib is the basic data visualization tool of Python programming language
#
# Matplotlib was created by John D. Hunter.
#
# Matplotlib is open source and we can use it freely.
#
# Matplotlib is mostly written in python, a few segments are written in C, Objective-C and Javascript for Platform compatibility.

# %% [markdown]
# # Data Visualization:-
# The process of conveying the information with the help of plots and graphics is called Data Visualization.
#
# -->The plots and graphics take numerical data as input and display output in the form of charts, figures and tables.
# -->It helps to analyze and visualize the data clearly and make concrete decisions.
# -->It makes complex data more accessible and understandable.
# -->The goal of data visualization is to communicate information in a clear and efficient manner.

# %%
#importing matplotlib
import matplotlib

# %%
print(matplotlib.__version__)
# Out:
# 3.4.3

# %%
#we have to work with **pyplot** interface of Matplotlib. So, I will import **pyplot** interface of Matplotlib as follows:-


import matplotlib.pyplot as plt

# %%
# Import dependencies
import numpy as np 
import pandas as pd

# %%
# Import Matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# # Displaying Plots in Matplotlib
#
# Displaying plots in Matplotlib means showing graphs (line chart, bar chart, scatter plot, etc.) using the matplotlib.pyplot module. The main function used to display a plot is:
#
# plt.show()

# %% [markdown]
# # Plotting from a Jupyter notebook
#
#
# The Jupyter Notebook is a data analysis and visualization tool that provides multiple tools under one roof.
# It provides code execution, graphical plots, rich text and media display, mathematics formula and much more facilities into a single executable document.
#
#
# Interactive plotting within a Jupyter Notebook can be done with the **%matplotlib** command. There are two possible options to work with graphics in Jupyter Notebook. These are as follows:-
#
#
# •	**%matplotlib notebook** – This command will produce interactive plots embedded within the notebook.
#
# •	**%matplotlib inline** – It will output static images of the plot embedded in the notebook.
#
#
# After this command (it needs to be done only once per kernel per session), any cell within the notebook that creates a plot will embed a PNG image of the graphic.

# %% [markdown]
# # Explanation1:-
#
# plt.plot(x,y) → creates line graph
#
# plt.title() → adds title
#
# plt.xlabel() → X-axis label
#
# plt.ylabel() → Y-axis label
#
# plt.show() → displays the graph window

# %%
import matplotlib.pyplot as plt

x = [1,2,3,4]
y = [10,20,25,30]

plt.plot(x,y)
plt.title("Simple Line Plot")
plt.xlabel("X Axis")
plt.ylabel("Y Axis")

plt.show()

# %% [markdown]
# # explanation2:
#
# #np.linspace(start, stop, number_of_values) is a NumPy function that creates evenly spaced numbers over a specified interval.
# #So it creates 50 evenly spaced numbers between 0 and 10.
#
# #plt.figure() creates a new empty plotting window (figure) where graphs will be drawn.
#
# #fig = plt.figure() It creates a figure object where multiple plots can be drawn.
#
# #plt.plot() is a Matplotlib function used to create a line graph
#
# *****np.sin(x1) sine of each value
# *****np.cos(x1) cosine values
# ****'-'  solid line style
# ****** '--' dashed line style

# %%
# %matplotlib inline
x1 = np.linspace(0, 10, 50)  
                            
# create a plot figure
#fig = plt.figure()        
                          

plt.plot(x1, np.sin(x1), '-')
plt.plot(x1, np.cos(x1), '--')
#plt.plot(x1, np.tan(x1), '--')
plt.show()

# %% [markdown]
# # Pyplot API
#
# The Pyplot API is a collection of functions in Matplotlib that allow you to create plots and charts easily using a MATLAB-style interface.
# Matplotlib utilities lies under the pyplot submodule, and are usually imported under the plt alias:
#
# import matplotlib.pyplot as plt
#
# **matplotlib → Visualization library
#
# **pyplot → Module used to create plots
#
# **plt → common alias used by programmers
#
#
#
# *******Common Pyplot API Functions
# Function	        Purpose
# =====================
# plt.plot()	              Line chart
# plt.scatter()	          Scatter plot
# plt.bar()	              Bar chart
# plt.hist()            	  Histogram
# plt.pie()	              Pie chart
# plt.title()	               Chart title
# plt.xlabel()	           X-axis label
# plt.ylabel()	           Y-axis label
# plt.legend()	           Show legend
# plt.grid()	             Display grid lines
# plt.xlim()	              Set X-axis range
# plt.ylim()	             Set Y-axis range
# plt.figure()	            Create new figure
# plt.subplots()	             Create figure + axes
# plt.show()	                 Display the plot

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0, 6])
ypoints = np.array([0, 250])

plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt

x = [1,2,3,4]
y = [10,15,20,25]

plt.plot(x,y)

plt.title("Sales Growth")
plt.xlabel("Month")
plt.ylabel("Sales")

plt.grid()

plt.show()

# %%
import matplotlib.pyplot as plt

months = ["Jan","Feb","Mar","Apr"]
sales = [100,120,150,170]

plt.plot(months, sales, marker='o')

plt.title("Monthly Sales")
plt.xlabel("Month")
plt.ylabel("Sales")

plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt

fig = plt.figure()
fig, ax = plt.subplots()
ax.set_xlabel("Month")
ax.set_ylabel("Sales")
# Out:
# Text(0, 0.5, 'Sales')

# %% [markdown]
# # State-machine interface
#
# Pyplot provides the state-machine interface to the underlying object-oriented plotting library. The state-machine implicitly and automatically creates figures and axes to achieve the desired plot. For example:
#
#
# np.linspace() is a NumPy function that generates evenly spaced numbers within a specified range.So Python creates 100 evenly spaced values between 0 and 2.
#
# plt.plot(x, x, label='linear')  --> Plot Linear Function
# plt.plot(x, x**2, label='quadratic') --> Plot Quadratic Function
# plt.plot(x, x**3, label='cubic')    --> Plot Cubic Function

# %%
x = np.linspace(0, 2, 100)

plt.plot(x, x, label='linear')
plt.plot(x, x**2, label='quadratic')
plt.plot(x, x**3, label='cubic')

plt.xlabel('x label')
plt.ylabel('y label')

plt.title("Simple Plot")

plt.legend()

plt.show()

# %% [markdown]
# # Formatting the style of plot
#
#
# For every x, y pair of arguments, there is an optional third argument which is the format string that indicates the color and line type of the plot. The letters and symbols of the format string are from MATLAB. We can concatenate a color string with a line style string. The default format string is 'b-', which is a solid blue line. For example, to plot the above line with red circles, we would issue the following command:-

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'ro')
plt.axis([0, 6, 0, 20])   # takes a list of [xmin, xmax, ymin, ymax]
plt.show()

# %% [markdown]
# # Working with NumPy arrays
#
#
# Generally, we have to work with NumPy arrays. All sequences are converted to numpy arrays internally. The below example illustrates plotting several lines with different format styles in one command using arrays.

# %%
# evenly sampled time at 200ms intervals
t = np.arange(0., 5., 0.2)    # starts with 0.2 and end with 5.0 with an interval of 0.2

# red dashes, blue squares and green triangles
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()

# %% [markdown]
# # Mini Data Analytics Visualization Project
#
# **Sales Data Analysis

# %%
#Step 1: Import Libraries

import pandas as pd
import matplotlib.pyplot as plt

# %%
#Step 2: Create Dataset

data = {"Month":["Jan","Feb","Mar","Apr","May"],"Sales":[200,250,300,280,350],"Profit":[50,70,90,80,110]}

df = pd.DataFrame(data)

# %%
#Step 3: View Dataset
print(df)
# Out:
#   Month  Sales  Profit
# 0   Jan    200      50
# 1   Feb    250      70
# 2   Mar    300      90
# 3   Apr    280      80
# 4   May    350     110

# %%
#Step 4: Sales Trend Visualization

plt.plot(df["Month"], df["Sales"], marker='o')

plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Sales")

plt.show()

# %%
#Step 5: Profit Bar Chart

plt.bar(df["Month"], df["Profit"])

plt.title("Monthly Profit")
plt.xlabel("Month")
plt.ylabel("Profit")

plt.show()

# %%
#step5 pie chart
plt.pie(df["Sales"], labels=df["Month"], autopct='%1.1f%%')

plt.title("Sales Distribution by Month")

plt.show()
